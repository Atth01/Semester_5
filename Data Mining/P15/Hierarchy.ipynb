# %%
#import Library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as shc
from sklearn.cluster import AgglomerativeClustering
from sklearn import metrics
import seaborn as sns

# %%
#Menggunakan Dataset Array
X=np.array([[7,6],[6,3],[7,5],[6,2],[5,8],[2,6],[3,2],[2,8]])
print(X)
# Out:
# [[7 6]
#  [6 3]
#  [7 5]
#  [6 2]
#  [5 8]
#  [2 6]
#  [3 2]
#  [2 8]]

# %%
#VISUALISASI DENDOGRAM
data = X
plt.figure(figsize=(10,7))
dend = shc.dendrogram(shc.linkage(data, method='single'))

# %%
#Dataset menggunakan table
dataset = pd.read_excel('Pengunjung_mall.xlsx')
dataset.head()
# Out:
#    IDPelanggan    Kelamin  Usia  Pendapatan  Pengeluaran
# 0            1       Laki    19          15           39
# 1            2       Laki    21          15           81
# 2            3  Perempuan    20          16            6
# 3            4  Perempuan    23          16           77
# 4            5  Perempuan    31          17           40

# %%
#Konversi Dataset Table (Data Frame) to Array
dataset = pd.read_excel('Pengunjung_mall.xlsx')
Y = dataset.iloc[:, [3, 4]].values
print(Y)
# Out:
# [[ 15  39]
#  [ 15  81]
#  [ 16   6]
#  [ 16  77]
#  [ 17  40]
#  [ 17  76]
#  [ 18   6]
#  [ 18  94]
#  [ 19   3]
#  [ 19  72]
#  [ 19  14]
#  [ 19  99]
#  [ 20  15]
#  [ 20  77]
#  [ 20  13]
#  [ 20  79]
#  [ 21  35]
#  [ 21  66]
#  [ 23  29]
#  [ 23  98]
#  [ 24  35]
#  [ 24  73]
#  [ 25   5]
#  [ 25  73]
#  [ 28  14]
#  [ 28  82]
#  [ 28  32]
#  [ 28  61]
#  [ 29  31]
#  [ 29  87]
#  [ 30   4]
#  [ 30  73]
#  [ 33   4]
#  [ 33  92]
#  [ 33  14]
#  [ 33  81]
#  [ 34  17]
#  [ 34  73]
#  [ 37  26]
#  [ 37  75]
#  [ 38  35]
#  [ 38  92]
#  [ 39  36]
#  [ 39  61]
#  [ 39  28]
#  [ 39  65]
#  [ 40  55]
#  [ 40  47]
#  [ 40  42]
#  [ 40  42]
#  [ 42  52]
#  [ 42  60]
#  [ 43  54]
#  [ 43  60]
#  [ 43  45]
#  [ 43  41]
#  [ 44  50]
#  [ 44  46]
#  [ 46  51]
#  [ 46  46]
#  [ 46  56]
#  [ 46  55]
#  [ 47  52]
#  [ 47  59]
#  [ 48  51]
#  [ 48  59]
#  [ 48  50]
#  [ 48  48]
#  [ 48  59]
#  [ 48  47]
#  [ 49  55]
#  [ 49  42]
#  [ 50  49]
#  [ 50  56]
#  [ 54  47]
#  [ 54  54]
# ...

# %%
#VISUALISASI DENDOGRAM
data = Y
plt.figure(figsize=(10,7))
dend = shc.dendrogram(shc.linkage(data, method='ward'))
